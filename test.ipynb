# %%
using Pkg
Pkg.add("WooldridgeDatasets")
using WooldridgeDatasets
using CSV
using DataFrames
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\ay440\.julia\environments\v1.8\Project.toml`
#   No Changes to `C:\Users\ay440\.julia\environments\v1.8\Manifest.toml`
# 0×0 DataFrame

# %%
test = DataFrame()
# Out:
# 0×0 DataFrame

# %%
test = DataFrame(wooldridge("rental"))
# Out:
# 128×23 DataFrame
#  Row │ city   year   pop       enroll   rent   rnthsg   tothsg   avginc   lenr ⋯
#      │ Int64  Int64  Float64   Float64  Int64  Float64  Float64  Float64  Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     1     80   75211.0  15303.0    197  13475.0  26167.0  11537.0   9.6 ⋯
#    2 │     1     90   77759.0  18017.0    342  15660.0  29467.0  19568.0   9.7
#    3 │     2     80  106743.0  22462.0    323  14580.0  37277.0  19841.0  10.0
#    4 │     2     90  141865.0  29769.0    496  26895.0  55540.0  31885.0  10.3
#    5 │     3     80   36608.0  11847.0    216   7026.0  13482.0  11455.0   9.3 ⋯
#    6 │     3     90   42099.0  10265.0    351   9557.0  16894.0  21202.0   9.2
#    7 │     4     80   36640.0  13825.0    267   7896.0  14041.0  14682.0   9.5
#    8 │     4     90   46209.0  18173.0    588  10617.0  17926.0  29044.0   9.8
# ...

# %%
Pkg.add("StatsKit")
using StatsKit
# Out:
#    Resolving package versions...
#    Installed Bootstrap ────────── v2.3.3
#    Installed OffsetArrays ─────── v1.12.9
#    Installed SpecialFunctions ─── v2.2.0
#    Installed StaticArrays ─────── v1.5.16
#    Installed MutableArithmetics ─ v1.2.3
#    Installed MixedModels ──────── v4.8.2
#    Installed Arrow ────────────── v2.4.3
#    Installed NaNMath ──────────── v1.0.2
#    Installed Rmath_jll ────────── v0.4.0+0
#    Installed Lz4_jll ──────────── v1.9.3+0
#    Installed Loess ────────────── v0.5.4
#    Installed StructTypes ──────── v1.10.0
#    Installed HypothesisTests ──── v0.10.11
#    Installed TimeSeries ───────── v0.23.1
#    Installed Zstd_jll ─────────── v1.5.4+0
#    Installed MathOptInterface ─── v1.12.0
#    Installed JSON3 ────────────── v1.12.0
#    Installed LogExpFunctions ──── v0.3.23
#    Installed MultivariateStats ── v0.10.1
#    Installed CodecLz4 ─────────── v0.4.0
#    Installed ChainRulesCore ───── v1.15.7
#    Installed Adapt ────────────── v3.5.0
# ...

# %%
Pkg.rm("StatsKit")
# Out:
#     Updating `C:\Users\ay440\.julia\environments\v1.8\Project.toml`
#   [2cb19f9e] - StatsKit v0.3.1
#     Updating `C:\Users\ay440\.julia\environments\v1.8\Manifest.toml`
#   [621f4979] - AbstractFFTs v1.2.1
#   [79e6a3ab] - Adapt v3.5.0
#   [7d9fca2a] - Arpack v0.5.4
#   [69666777] - Arrow v2.4.3
#   [31f734f8] - ArrowTypes v2.0.2
#   [13072b0f] - AxisAlgorithms v1.0.1
#   [6e4b80f9] - BenchmarkTools v1.3.2
#   [c3b6d118] - BitIntegers v0.2.7
#   [e28b5b4c] - Bootstrap v2.3.3
#   [fa961155] - CEnum v0.4.2
#   [49dc2e85] - Calculus v0.5.1
#   [324d7699] - CategoricalArrays v0.10.7
#   [d360d2e6] - ChainRulesCore v1.15.7
#   [9e997f8a] - ChangesOfVariables v0.1.6
#   [aaaa29a8] - Clustering v0.14.3
#   [523fee87] - CodecBzip2 v0.7.2
#   [5ba52731] - CodecLz4 v0.4.0
#   [6b39b394] - CodecZstd v0.7.2
#   [861a8166] - Combinatorics v1.0.2
#   [38540f10] - CommonSolve v0.2.3
#   [bbf7d656] - CommonSubexpressions v0.3.0
#   [187b0558] - ConstructionBase v1.4.1
# ...

# %%
# Out:
# ArgumentError: Package LinearRegressionKit not found in current path.
# - Run `import Pkg; Pkg.add("LinearRegressionKit")` to install the LinearRegressionKit package.
#
# Stacktrace:
#  [1] macro expansion
#    @ .\loading.jl:1163 [inlined]
#  [2] macro expansion
#    @ .\lock.jl:223 [inlined]
#  [3] require(into::Module, mod::Symbol)
#    @ Base .\loading.jl:1144
